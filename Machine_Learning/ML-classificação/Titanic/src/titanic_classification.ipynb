# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import(
    ensemble,
    preprocessing,
    tree
)

# %%
from sklearn.metrics import (
    auc,
    confusion_matrix,
    roc_auc_score,
    roc_curve
)

# %%
from sklearn.model_selection import(
    train_test_split,
    StratifiedKFold,
    KFold,
    cross_val_score
)

# %%
from yellowbrick.classifier import (
    ConfusionMatrix,
    ROCAUC
)

# %%
from yellowbrick.model_selection import(
    learning_curve
)

# %% [markdown]
# # Titanic (Exemplo didático para fixação do conteúdo do curso de Scikit-Learn)
# ***
# Neste exemplo queremos criar um modelo preditivo para responder a uma pergunta. Ele classificará se um indivíduo sobreviveu à catastrofe do navio Titanic com base nas características individuais e da viagem.

# %%
# url = "http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls"
file = "titanic3.xls"
df = pd.read_excel(file)
orig_df = df.copy()
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-06-30 09:31:46.264671&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.describe().iloc[:, :2]
# Out:
#             pclass     survived
# count  1309.000000  1309.000000
# mean      2.294882     0.381971
# std       0.837836     0.486055
# min       1.000000     0.000000
# 25%       2.000000     0.000000
# 50%       3.000000     0.000000
# 75%       3.000000     1.000000
# max       3.000000     1.000000

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# ### Calculando a porcentagem de valores ausentes no DataFrame
# ***

# %%
(df.isnull().sum()/df.shape[0]) * 100
# Out:
# pclass        0.000000
# survived      0.000000
# name          0.000000
# sex           0.000000
# age          20.091673
# sibsp         0.000000
# parch         0.000000
# ticket        0.000000
# fare          0.076394
# cabin        77.463713
# embarked      0.152788
# boat         62.872422
# body         90.756303
# home.dest    43.086325
# dtype: float64

# %% [markdown]
# As colunas com mais de 50% podem ser descartadas, pq seria um pouco complicado interpola-las para preencher os dados missing.

# %%
df.drop(columns=['body', 'cabin', 'boat'], axis=1, inplace=True)
df.sample(10)
# Out:
#       pclass  survived                                   name     sex   age  \
# 927        3         0                     Khalil, Mr. Betros    male   NaN
# 909        3         1                    Jussila, Mr. Eiriik    male  32.0
# 1103       3         0           Panula, Master. Urho Abraham    male   2.0
# 1285       3         0                    Wenzel, Mr. Linhart    male  32.5
# 159        1         1           Hippach, Miss. Jean Gertrude  female  16.0
# 640        3         0  Asplund, Master. Clarence Gustaf Hugo    male   9.0
# 752        3         0                   Davies, Mr. Alfred J    male  24.0
# 655        3         0             Backstrom, Mr. Karl Alfred    male  32.0
# 219        1         1              Omont, Mr. Alfred Fernand    male   NaN
# 1057       3         1            Nicola-Yarred, Miss. Jamila  female  14.0
#
#       sibsp  parch             ticket     fare embarked  \
# 927       1      0               2660  14.4542        C
# ...

# %%
mask=df.isnull().any(axis=1) # mascara para inspecionar algumas linhas com dados faltantes.
mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[mask].age.head()
# Out:
# 13    26.0
# 15     NaN
# 18    32.0
# 23    42.0
# 24    29.0
# Name: age, dtype: float64

# %%
df.sex.value_counts(dropna=False)
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
pivot_gender_survived = pd.pivot_table(df, 
                                       values = ['survived'],
                                       index = 'sex',
                                       aggfunc=np.mean)
pivot_gender_survived
# Out:
#         survived
# sex
# female  0.727468
# male    0.190985

# %%
_ = df.groupby('survived').sex.value_counts().unstack(0).plot.barh()
plt.close()
plt.show()

# %%
df.embarked.value_counts(dropna=False) # dropna=False para incluir os dados faltantes
# Out:
# S      914
# C      270
# Q      123
# NaN      2
# Name: embarked, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'embarked',
#  'home.dest']

# %%
df = df.drop(columns=['name', 'ticket', 'home.dest'])
df=pd.get_dummies(df, drop_first=True)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'age', 'sibsp', 'parch', 'fare', 'sex_male',
#        'embarked_Q', 'embarked_S'],
#       dtype='object')

# %%
y=df.survived
X=df.drop(columns='survived')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Imputação dos dados ausentes
# ***

# %%
from sklearn.experimental import(
    enable_iterative_imputer
)
from sklearn import impute
num_cols=X.select_dtypes(include=['int64', 'float64']).columns
num_cols = ["pclass", "age", "sibsp", "parch", "sex_male", "fare"]

# %%
imputer = impute.IterativeImputer()
imputed=imputer.fit_transform(X_train[num_cols])
X_train.loc[:, num_cols] = imputed
imputed = imputer.transform(X_test[num_cols])
X_test.loc[:, num_cols] = imputed
# Out:
# /home/fabio/projects/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# /home/fabio/projects/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
cols = ['pclass', 'age', 'sibsp', 'parch', 'fare', 'sex_male',
   'embarked_Q', 'embarked_S']
sca = preprocessing.StandardScaler()
X_train = sca.fit_transform(X_train)
X_train = pd.DataFrame(X_train, columns=cols)
X_test = sca.transform(X_test)
X_test = pd.DataFrame(X_test, columns=cols)

# %% [markdown]
# ## Refatorando o código
# ***

# %%
def tweak_titanic(df):
    df = df.drop(
        columns=[
            "name",
            "ticket",
            "home.dest",
            "boat",
            "body",
            "cabin",
        ]
    ).pipe(pd.get_dummies, drop_first=True)
    return df

# %%
def get_train_test_X_y(
    df, y_col, size=0.3, std_cols=None
):
    y = df[y_col]
    X = df.drop(columns=y_col)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=size, random_state=42
    )
    cols = X.columns
    num_cols = [
        "pclass",
        "age",
        "sibsp",
        "parch",
        "fare",
    ]
    fi = impute.IterativeImputer()
    fitted = fi.fit_transform(X_train[num_cols])
    X_train = X_train.assign(**{c:fitted[:,i] for i, c in enumerate(num_cols)})
    test_fit = fi.transform(X_test[num_cols])
    X_test = X_test.assign(**{c:test_fit[:,i] for i, c in enumerate(num_cols)})
    if std_cols:
        std = preprocessing.StandardScaler()
        fitted = std.fit_transform(X_train[std_cols])
        X_train = X_train.assign(**{c:fitted[:,i] for i, c in enumerate(std_cols)})
        test_fit = std.transform(X_test[std_cols])
        X_test = X_test.assign(**{c:test_fit[:,i] for i, c in enumerate(std_cols)})

    return X_train, X_test, y_train, y_test

# %%
ti_df = tweak_titanic(orig_df)
std_cols = "pclass,age,sibsp,fare".split(",")
X_train, X_test, y_train, y_test = get_train_test_X_y(
    ti_df, "survived", std_cols=std_cols
)

# %% [markdown]
# ## Modelo de base
# ***

# %%
from sklearn.dummy import DummyClassifier
bm = DummyClassifier()
bm.fit(X_train, y_train)
bm.score(X_test, y_test)  # accuracy
# Out:
# 0.5699745547073791

# %%
from sklearn import metrics
metrics.precision_score(
    y_test, bm.predict(X_test)
)
# Out:
# /home/fabio/projects/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.0

# %%
X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])
from sklearn import model_selection
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import (
    LogisticRegression,
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import (
    KNeighborsClassifier,
)
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import (
    RandomForestClassifier,
)
import xgboost

# %%
for model in [
    DummyClassifier,
    LogisticRegression,
    DecisionTreeClassifier,
    KNeighborsClassifier,
    GaussianNB,
    SVC,
    RandomForestClassifier,
    xgboost.XGBClassifier,
]:
    cls = model()
    kfold = KFold(
        n_splits=10, random_state=42, shuffle=True
    )
    s = cross_val_score(
        cls, X, y, scoring="roc_auc", cv=kfold
    )
    print(
        f"{model.__name__:22}  AUC: "
        f"{s.mean():.3f} STD: {s.std():.2f}"
    )
# Out:
# DummyClassifier         AUC: 0.500 STD: 0.00
# LogisticRegression      AUC: 0.840 STD: 0.04
# DecisionTreeClassifier  AUC: 0.751 STD: 0.04
# KNeighborsClassifier    AUC: 0.825 STD: 0.03
# GaussianNB              AUC: 0.811 STD: 0.05
# SVC                     AUC: 0.838 STD: 0.03
# RandomForestClassifier  AUC: 0.846 STD: 0.02
# [06:33:19] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [06:33:20] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
from mlxtend.classifier import (
    StackingClassifier,
)
clfs = [
    x()
    for x in [
        LogisticRegression,
        DecisionTreeClassifier,
        KNeighborsClassifier,
        GaussianNB,
        SVC,
        RandomForestClassifier,
    ]
]
stack = StackingClassifier(
    classifiers=clfs,
    meta_classifier=LogisticRegression(),
)
kfold = model_selection.KFold(
    n_splits=10, random_state=42, shuffle =True
)
s = model_selection.cross_val_score(
    stack, X, y, scoring="roc_auc", cv=kfold
)
print(
    f"{stack.__class__.__name__}  "
    f"AUC: {s.mean():.3f}  STD: {s.std():.2f}"
)
# Out:
# StackingClassifier  AUC: 0.791  STD: 0.02

# %%
rf = ensemble.RandomForestClassifier(
    n_estimators=100, random_state=42
)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf.score(X_test, y_test)
# Out:
# 0.7837150127226463

# %%
metrics.precision_score(
    y_test, rf.predict(X_test)
)
# Out:
# 0.7916666666666666

# %%
for col, val in sorted(
    zip(
        X_train.columns,
        rf.feature_importances_,
    ),
    key=lambda x: x[1],
    reverse=True,
)[:5]:
    print(f"{col:10}{val:10.3f}")
# Out:
# age            0.285
# fare           0.262
# sex_male       0.241
# pclass         0.089
# sibsp          0.050

# %%
rf4 = ensemble.RandomForestClassifier()
params = {
    "max_features": [0.4, "auto"],
    "n_estimators": [15, 200],
    "min_samples_leaf": [1, 0.1],
    "random_state": [42],
}
cv = model_selection.GridSearchCV(
    rf4, params, n_jobs=-1
).fit(X_train, y_train)
print(cv.best_params_)
# Out:
# {'max_features': 0.4, 'min_samples_leaf': 1, 'n_estimators': 200, 'random_state': 42}

# %%
rf5 = ensemble.RandomForestClassifier(
    **{
        "max_features": "auto",
        "min_samples_leaf": 0.1,
        "n_estimators": 200,
        "random_state": 42,
    }
)
rf5.fit(X_train, y_train)
rf5.score(X_test, y_test)
# Out:
# 0.7073791348600509

# %%
from sklearn.metrics import confusion_matrix
y_pred = rf5.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[217,   7],
#        [108,  61]])

# %%
mapping = {0: "died", 1: "survived"}
fig, ax = plt.subplots(figsize=(6, 6))
cm_viz = ConfusionMatrix(
    rf5,
    classes=["died", "survived"],
    label_encoder=mapping,
)
cm_viz.score(X_test, y_test)
cm_viz.poof()
# Out:
# /home/fabio/projects/venv/lib/python3.9/site-packages/yellowbrick/classifier/base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(
# <AxesSubplot:title={'center':'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
y_pred = rf5.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.6648483727810651

# %%
fig, ax = plt.subplots(figsize=(6, 6))
roc_viz = ROCAUC(rf5)
roc_viz.score(X_test, y_test)
roc_viz.poof()
# Out:
# /home/fabio/projects/venv/lib/python3.9/site-packages/yellowbrick/classifier/base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-a8305f368e98> in <module>
#       1 fig, ax = plt.subplots(figsize=(6, 6))
#       2 roc_viz = ROCAUC(rf5)
# ----> 3 roc_viz.score(X_test, y_test)
#       4 roc_viz.poof()
#
# ~/projects/venv/lib/python3.9/site-packages/yellowbrick/classifier/rocauc.py in score(self, X, y)
#     264         y_pred = self._get_y_scores(X)
#     265
# --> 266         if self.target_type_ == BINARY:
#     267             # For binary, per_class must be True to draw micro/macro curves
#     268             if (self.micro or self.macro) and not self.per_class:
#
# ...

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(6, 4))
cv = StratifiedKFold(12)
sizes = np.linspace(0.3, 1.0, 10)
lc_viz = learning_curve(X,y,
    rf5,
    cv=cv,
    train_sizes=sizes,
    scoring="f1_weighted",
    n_jobs=4,
    ax=ax,
)
lc_viz.fit(X, y)
lc_viz.poof()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# <ipython-input-53-6d48da3628c2> in <module>
#       3 cv = StratifiedKFold(12)
#       4 sizes = np.linspace(0.3, 1.0, 10)
# ----> 5 lc_viz = learning_curve(X,y,
#       6     rf5,
#       7     cv=cv,
#
# ~/projects/venv/lib/python3.9/site-packages/yellowbrick/model_selection/learning_curve.py in learning_curve(estimator, X, y, ax, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, shuffle, random_state, show, **kwargs)
#     425     """
#     426     # Initialize the visualizer
# --> 427     oz = LearningCurve(
#     428         estimator,
#     429         ax=ax,
#
# ...

# %%
from sklearn.metrics import plot_roc_curve

disp = plot_roc_curve(rf5, X_test, y_test)


_ = disp.ax_.set_title("ROC AUC curve")

# %% [markdown]
# # Persistência dos modelos
# ***

# %%
import pickle
pic = pickle.dumps(rf5)
rf6 = pickle.loads(pic)
y_pred = rf6.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.6648483727810651
